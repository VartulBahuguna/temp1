# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import spacy 
from spacy.lang.en import English
from spacy.pipeline import EntityRuler
import json
from nltk.stem.porter import PorterStemmer
import random
from spacy.training.example import Example
from spacy.tokens import Doc
from string import punctuation
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import *
from nltk.tokenize import sent_tokenize
from nltk import WordPunctTokenizer
import regex as re
stemmer = WordNetLemmatizer()
nltk.download('wordnet')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\VARTUL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VARTUL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\VARTUL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#importing data set

df = pd.read_csv("C:\\Users\\VARTUL\\Desktop\\DA07.csv")
print(df.shape)
df = df.dropna()
# Out:
# (5128, 10)

# %%
#Stopwords removal and Tokenization

df['Event Type'] = df['Event Type'].apply(str)
ls =df['Event Type'].to_list()
n = len(ls)
ps = ls.copy()
for i in range(0,n):
    s = ls[i]
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(s)
    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
    ls[i].join(filtered_sentence)
    ls[i] = ls[i].lower()

# %%
#Removing unwanted words (not related to crime)

unique = list(set(ls))

        
words = []    
for i in unique:
    j = i.replace('(', " ").replace(')', " ").replace('/', " ").replace('-', " ")
    a=j.split(" ")
    for word in a:
        words.append(word.strip())
words = list(set(words))
words.sort()
rem = ['by', 'code', 'abled', 'act', 'corona', 'for', 'against', 'in', 'jam', 'media','information',
 'internet','government','mobile','model','on','pocket','phone','other','people','small','pick','person',
 'medium', 'mining','police','unclaimed','help','object','attempt','cyber','departments','fire','found',
 'differently','social','safety','personally','escort','missing','major','election','conduct','attempted','of','human','unknown','pollution','property','related','required','']
for i in rem:
    words.remove(i)

# %%
#classifying key words according to their severity 

l1 = ['trafficking', 'election Offences', 'explosive', 
      'murder','assault','riot', 
      'deadbody', 'fire', 'rape', 'ndps', ]
l2 = ['suicide', 'accident', 'smugling', 'violation','offenses',
     'crime', 'kidnap', 'harrassment', 'sexual'
      'domestic','assault'
     ]
l3 = ['gambling', 'offenses',  'forgery', 'threat','suspicious',
      'illegal', 'robbery', 'abuse','female','sos','theft','violence'
 'accident','animals','child','commotion','crimes','crime','dispute',
 'disputes','dacoity','dowry','encroachment','excise','illegal','108',
 '1090']

# %%
#function to create patterns

def create_patterns(t, ls):
    patterns = []
    for item in ls:
        pattern = {
            "label":t,
            "pattern":item
        }
        
        patterns.append(pattern)
    return patterns

# %%
pattern1 = create_patterns('L1', l1)
pattern2 = create_patterns('L2', l2)
pattern3 = create_patterns('L3', l3) 
patterns = pattern1+pattern2+pattern3

# %%
#generating rules with created patterns

def gen_rules(patterns):
    nlp = English()
    ruler = nlp.add_pipe("entity_ruler")
    ruler.add_patterns(patterns)
    nlp.to_disk("crime_ner")

# %%
gen_rules(patterns)

# %%
nlp = spacy.load('crime_ner')

# %%
#creating Train-dataset 

def test_model(model, text):
    doc = nlp(text)
    results = []
    entities = []
    for ent in doc.ents:
        entities.append((ent.start_char, ent.end_char, ent.label_))
    if(len(entities) > 0):
        results = (text, {'entities': entities})
        return results

# %%
def save_data(file, data):
    with open(file, 'w', encoding = 'utf-8')as f:
        json.dump(data, f, indent=4)

# %%
res = []
TRAIN_DATA = []
for i in ls:
    result = test_model(nlp, i)
    res.append(result)
    if result != None:
        TRAIN_DATA.append(result)
save_data('data/crime_training_data.json', TRAIN_DATA)

# %%
def load_data(file):
    with open(file, "r", encoding='utf-8') as f:
        data = json.load(f)
    return data

# %%
TRAIN_DATA = load_data('data/crime_training_data.json')
TRAIN_DATA
# Out:
# [['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['illegal mining', {'entities': [[0, 7, 'L3']]}],
#  ['suicide', {'entities': [[0, 7, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['suicide', {'entities': [[0, 7, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['encroachment', {'entities': [[0, 12, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['illegal mining', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['encroachment', {'entities': [[0, 12, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['illegal mining', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['child crime(sexual abuse)', {'entities': [[0, 5, 'L3'], [19, 24, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['suspicious object information', {'entities': [[0, 10, 'L3']]}],
#  ['threat on phone email social media', {'entities': [[0, 6, 'L3']]}],
#  ['dacoity', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['illegal mining', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['forgery', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['female harrassment', {'entities': [[0, 6, 'L3'], [7, 18, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['excise act offenses', {'entities': [[0, 6, 'L3'], [11, 19, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['accident', {'entities': [[0, 8, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dacoity', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['ndps act offenses', {'entities': [[0, 4, 'L1'], [9, 17, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['police help required by 108', {'entities': [[24, 27, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['excise act offenses', {'entities': [[0, 6, 'L3'], [11, 19, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['female harrassment', {'entities': [[0, 6, 'L3'], [7, 18, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['ndps act offenses', {'entities': [[0, 4, 'L1'], [9, 17, 'L2']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['accident', {'entities': [[0, 8, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['illegal mining', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['encroachment', {'entities': [[0, 12, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['female harrassment', {'entities': [[0, 6, 'L3'], [7, 18, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['suspicious object information', {'entities': [[0, 10, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['child crime(sexual abuse)', {'entities': [[0, 5, 'L3'], [19, 24, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['accident', {'entities': [[0, 8, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['female harrassment', {'entities': [[0, 6, 'L3'], [7, 18, 'L2']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['murder', {'entities': [[0, 6, 'L1']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['suicide', {'entities': [[0, 7, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['forgery', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['encroachment', {'entities': [[0, 12, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['assault/riot/commotion',
#   {'entities': [[0, 7, 'L2'], [8, 12, 'L1'], [13, 22, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['major fire', {'entities': [[6, 10, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['female harrassment', {'entities': [[0, 6, 'L3'], [7, 18, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['found deadbody', {'entities': [[6, 14, 'L1']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['accident', {'entities': [[0, 8, 'L2']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['forgery', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['attempted murder', {'entities': [[10, 16, 'L1']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['animals related', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['suspicious person information', {'entities': [[0, 10, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['encroachment', {'entities': [[0, 12, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female harrassment', {'entities': [[0, 6, 'L3'], [7, 18, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['child crime', {'entities': [[0, 5, 'L3'], [6, 11, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['cyber crimes', {'entities': [[6, 12, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['kidnap', {'entities': [[0, 6, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['property disputes', {'entities': [[9, 17, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['sos', {'entities': [[0, 3, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['female sexual harrassment', {'entities': [[0, 6, 'L3'], [14, 25, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['medium fire', {'entities': [[7, 11, 'L1']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['robbery', {'entities': [[0, 7, 'L3']]}],
#  ['crime on phone mobile social media internet', {'entities': [[0, 5, 'L2']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['threat in person', {'entities': [[0, 6, 'L3']]}],
#  ['dispute', {'entities': [[0, 7, 'L3']]}],
#  ['gambling', {'entities': [[0, 8, 'L3']]}],
#  ['theft', {'entities': [[0, 5, 'L3']]}],
#  ...]

# %%
#Model Training process(Takes around 1hr)

def train_spacy(data, iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('en')
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe('ner', last = True)
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get('entities'):
            ner.add_label(ent[2])
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print('Starting Itertions ' + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for batch in spacy.util.minibatch(TRAIN_DATA, size=2):
                for text, annotations in batch:
                    doc = nlp.make_doc(text)
                    example = Example.from_dict(doc, annotations)
                    nlp.update(
                            [example],
                            drop = 0.2,
                            sgd = optimizer,
                            losses = losses
                    )
            print(losses)
    return nlp

# %%
# nlp = train_spacy(TRAIN_DATA, 30)
# nlp.to_disk('crime_ner_model')

# %%
tlp = spacy.load('crime_ner_model')

# %%
tlp
